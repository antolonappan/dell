# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
#from quest import Reconstruction
#from simulation import SimExperimentFG
from plotstat import recStat,simStat
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
saveplot = False

# %% [markdown]
# ### Simulation

# %%
sim1 = None#SimExperimentFG.from_ini('LB_FG0.ini')
sim2 = None#SimExperimentFG.from_ini('LB_FG1.ini')

# %%
sim = simStat(sim1,sim2)

# %%
sim.plot_fg2(save=saveplot)
# Out:
# Data Loaded from file

# %% [markdown]
# ### Reconstruction

# %%
rec1 = None#Reconstruction.from_ini('LB_FG0.ini')
rec2 = None#Reconstruction.from_ini('LB_FG1.ini')
rec3 = None#Reconstruction.from_ini('LB_FG2.ini')
rec4 = None#Reconstruction.from_ini('LB_FG2_p9.ini')

# %%
rec = recStat(rec1,rec2,rec3,rec4)

# %%
rec.plot_fg_impactNew(save=saveplot,planck=False,shift=1,logy=True)
# Out:
# Data Loaded from file

# %%
rec.plot_map_dif(save=saveplot,choose=4)
# Out:
# Input Map Loaded from file
# Output Map Loaded from file

# %%
rec.plot_qcl_stat(save=saveplot)
# Out:
# Data Loaded from file

# %%
rec.plot_SNR_impact(save=saveplot,color=['brown','gold','lightseagreen','blue','red','orchid'][::-1])
# Out:
# SNR Loaded from file

# %%
rec.plot_planck_comparsion(save=saveplot)

# %%
rec.plot_bin_corr_comp(1,save=saveplot)
# Out:
# Data Loaded from file

# %%
rec.plot_mismatching_alens(save=saveplot,do_MC=False)
# Out:
# Data Loaded from file

# %%
rec.plot_KS_pvalue(save=saveplot)

# %%
rec.plot_Alens_box(save=saveplot)
# Out:
# Data Loaded from file
