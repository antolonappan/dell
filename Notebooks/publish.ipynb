# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from plotstat import recStat,simStat

# %%
rec = recStat()
sim = simStat()

# %% [markdown]
# ### Simulation

# %%
#sim.plot_fg1(save=True)

# %%
sim.plot_fg2(save=True)
# Out:
# Data Loaded from file

# %% [markdown]
# ### Reconstruction

# %%
rec.plot_fg_impact(save=True,planck=False,shift=5)
# Out:
# Data Loaded from file

# %%
rec.plot_map_dif(save=True)
# Out:
# Input Map Loaded from file
# Output Map Loaded from file

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_402109/3844680658.py in <module>
# ----> 1 rec.plot_map_dif2()
#
# NameError: name 'rec' is not defined

# %%
rec.SNR_impact()
# Out:
# SNR Loaded from file
# SNR NOFG: 45.12
# SNR FG1: 40.88 decreased by 9.39 %
# SNR FG2: 40.03 decreased by 11.28 %

# %%
rec.plot_SNR_impact(save=True,color=['lightseagreen','deepskyblue','orchid'])
# Out:
# SNR Loaded from file

# %%
rec.plot_qcl_stat(save=True)
# Out:
# Data Loaded from file

# %%
#rec.plot_bin_corr_comp(2,save=True)

# %%
rec.plot_SNR_impact_v2(save=True,color=['brown','gold','lightseagreen','deepskyblue','orchid'][::-1])
# Out:
# SNR Loaded from file

# %%
rec.plot_planck_comparsion()
# Out:
# Data Loaded from file
