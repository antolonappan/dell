# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from plotstat import recStat,simStat
# Out:
# Running on VPS

# %%
rec = recStat()
sim = simStat()

# %%
rec.plot_qcl_stat()
# Out:
# Data Loaded from file

# %%
rec.plot_map_dif()
# Out:
# Input Map Loaded from file
# Output Map Loaded from file

# %%
rec.plot_fg_impact()
# Out:
# Data Loaded from file

# %%
rec.plot_bin_corr_comp(0)
# Out:
# Data Loaded from file
