# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
#from quest import Reconstruction
from plotstat import recStat,simStat
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rec1 = None#Reconstruction.from_ini('LB_FG0.ini')
rec2 = None#Reconstruction.from_ini('LB_FG1.ini')
rec3 = None#Reconstruction.from_ini('LB_FG2.ini')
rec4 = None#Reconstruction.from_ini('LB_FG2_p9.ini')

# %%
sim = simStat(None,None)

# %%
sim.plot_fg2(save=True)
# Out:
# Data Loaded from file

# %%
rec = recStat(rec1,rec2,rec3,rec4)

# %% [markdown]
# ### Simulation

# %% [markdown]
# ### Reconstruction

# %%
rec.plot_fg_impactNew(save=True,planck=False,shift=1,logy=True)
# Out:
# Data Loaded from file

# %%
rec.plot_map_dif(save=True,choose=4)
# Out:
# Input Map Loaded from file
# Output Map Loaded from file

# %%
rec.plot_qcl_stat(save=True)
# Out:
# Data Loaded from file

# %%
rec.plot_SNR_impact(save=True,color=['brown','gold','lightseagreen','blue','red','orchid'][::-1])
# Out:
# SNR Loaded from file

# %%
rec.plot_planck_comparsion(save=True)

# %%
rec.plot_bin_corr_comp(1,save=True)
# Out:
# Data Loaded from file

# %%
rec.plot_mismatching_alens(save=True,do_MC=False)
# Out:
# Data Loaded from file

# %%
rec.plot_KS_pvalue(save=True)

# %%
rec.plot_Alens_box(save=True)
# Out:
# Data Loaded from file
