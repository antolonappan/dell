# %%
import sys
sys.path.append('../')

# %%
import sn_estimates
# Out:
# S/N total case: old = 77.3
# S/N total case: MCN0_withoutFG = 71.8
# S/N total case: MCN0_withFG = 65.9
# S/N tomographic case: old = 87.6
# S/N tomographic case: MCN0_withoutFG = 81.1
# S/N tomographic case: MCN0_withFG = 74.4
